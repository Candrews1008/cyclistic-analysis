# %%
import pandas as pd
import duckdb

print("Jupyter is working!")

# %%
import pandas as pd
# First install duckdb using pip
# !pip install duckdb
# Then import it
import duckdb

print("Jupyter is working!")

# %%
import pandas as pd

# Install duckdb using pip
# !pip install duckdb

# Restart the kernel to make the installed package available
# Note: You'll need to manually restart the kernel after running this cell
# In most Jupyter interfaces: Kernel menu > Restart

# After restarting the kernel, run this in a new cell:
import duckdb

print("Jupyter is working!")

# %%
import pandas as pd

# Install duckdb using pip
# !pip install duckdb

# Restart the kernel to make the installed package available
# Note: You'll need to manually restart the kernel after running this cell
# In most Jupyter interfaces: Kernel menu > Restart

# After restarting the kernel, run this in a new cell:
import duckdb

print("Jupyter is working!")

# %%
import pandas as pd

# Install duckdb using pip
# !pip install duckdb

# %%
import duckdb

print("Jupyter is working!")

# %%
# First, install the duckdb package
# !pip install duckdb

# Then import it
import duckdb

print("Jupyter is working!")

# %%
# First, install the duckdb package
# !pip install duckdb

# Then import it
import duckdb

print("Jupyter is working!")

# %%
import duckdb

print("Jupyter is working!")

# %%
# !pip install duckdb

# %%
import duckdb

# %%
# !conda install -c conda-forge duckdb -y

# %%
import sys
# !{sys.executable} -m pip install duckdb

# %%
# !pip install duckdb==0.8.1  # Replace with an appropriate version

# %%
import duckdb

# %%
print("Jupyter is working!")

# %%
import duckdb

# %%
import pandas as pd
df = pd.read_parquet("data/processed/trips_clean.parquet")

# %%
df = pd.read_parquet("data/clean/trips_clean.parquet")

# %%
print(df.shape)
print(df.dtypes)
print(df["member_casual"].value_counts(dropna=False))
print(df["ride_length_min"].describe())

# %%
print(df["duration_min"].describe())

# %%
print(df["member_casual"].value_counts(dropna=False))

# %%
print(df.dtypes)

# %%
print(df.shape)

# %%
freq = df.groupby("member_casual").size().rename("rides")
dur  = df.groupby("member_casual")["duration_min"].agg(["mean","median"])
wday = df.groupby(["member_casual","weekday"]).size().rename("rides").reset_index()
hour = df.groupby(["member_casual","hour"]).size().rename("rides").reset_index()

freq, dur, wday.head(), hour.head()

# %%
df["weekday"] = df["started_at"].dt.day_name()

# %%
wday = (
    df.groupby(["member_casual","weekday"])
      .size()
      .rename("rides")
      .reset_index()
)

# %%
print(df.columns)

# %%
freq = df.groupby("member_casual").size().rename("rides")
dur  = df.groupby("member_casual")["duration_min"].agg(["mean","median"])
wday = df.groupby(["member_casual","weekday"]).size().rename("rides").reset_index()
hour = df.groupby(["member_casual","hour"]).size().rename("rides").reset_index()

freq, dur, wday.head(), hour.head()

# %%
df["hour"] = df["started_at"].dt.hour

# %%
hour = (
    df.groupby(["member_casual","hour"])
      .size()
      .rename("rides")
      .reset_index()
)

# %%
print(df[["started_at","hour"]].head())

# %%
freq = df.groupby("member_casual").size().rename("rides")
dur  = df.groupby("member_casual")["duration_min"].agg(["mean","median"])
wday = df.groupby(["member_casual","weekday"]).size().rename("rides").reset_index()
hour = df.groupby(["member_casual","hour"]).size().rename("rides").reset_index()

freq, dur, wday.head(), hour.head()

# %%
import matplotlib.pyplot as plt

# %%
dur["mean"].plot(kind="bar")
plt.title("Average Ride Duration (min) by Rider Type"); plt.ylabel("Minutes")
plt.show()

# %%
for typ, sub in hour.groupby("member_casual"):
    plt.plot(sub["hour"], sub["rides"], label=typ)
plt.title("Rides by Hour of Day"); plt.xlabel("Hour"); plt.ylabel("Rides"); plt.legend()
plt.show()

# %%
plt.savefig("visuals/rides_by_hour.png", dpi=200, bbox_inches="tight")

# %%
plt.savefig("visuals/avg_duration_by_rider.png", dpi=300, bbox_inches="tight")

# %%
git add notebooks/01_eda.ipynb visuals/* 2>/dev/null || true

# %%
# !git add notebooks/01_eda.ipynb visuals/* 2>/dev/null || true

# %%
# !git commit -m "feat: starter EDA notebook and plots"

# %%
# !git push

# %%
Candrews1008

# %%
# !git add notebooks/01_eda.ipynb visuals/* 2>/dev/null || true
# !git commit -m "feat: starter EDA notebook and plots"
# !git push

# %%
# %cd ~/Desktop/Portfolio_Projects/cyclistic-analysis

# %%
# !git rev-parse --show-toplevel

# %%
# %cd ~/Desktop/Portfolio_Projects/cyclistic-analysis

# %%
# !git rev-parse --show-toplevel

# %%
# !git branch --show-current
# !git remote -v
# !git status -s

# %%
# !ls -l notebooks/01_eda.ipynb
# !ls -l visuals

# %%
# !git branch --show-current
# !git remote -v
# !git status -s

# %%
# !ls -l notebooks/01_eda.ipynb
# !ls -l visuals

# %%
# %cd ~/Desktop/Portfolio_Projects/cyclistic-analysis
# !git rev-parse --show-toplevel

# %%
# !pwd
# !ls -1 *.ipynb || true
# !find . -maxdepth 3 -type f -name "*.ipynb"

# %%
# !ls -l notebooks

# %%
# !git add -A notebooks/01_eda.ipynb visuals/*.png

# %%
# !git mv "<eda.ipynb>" "notebooks/01_eda.ipynb"  ||

# %%
# %cd ~/Desktop/Portfolio_Projects/cyclistic-analysis

# %%
# !find . -maxdepth 3 -type f -name "*.ipynb"

# %%
# !git add visuals/*.png

# %%
# !git commit -m "feat: add starter EDA notebook and plots"

# %%
# !git push -u origin main   # or replace main with your branch name

# %%
# !git config --global user.name "Candrews1008"

# %%
# !git config --global user.email "candrews1008@gmail.com"

# %%
# !git commit -m "feat: add starter EDA notebook and plots"

# %%
# !git push -u origin main   # or replace main with your branch name

# %%
Candrews1008

# %%
# !git push -u origin main

# %%
Candrews1008

# %%
# !git push -u origin main

# %%
# !git config --global credential.helper store

# %%
# !git push -u origin main

# %%
# !git config --global credential.helper store
# !echo "https://Candrews1008:***REMOVED***@github.com" > ~/.git-credentials

# %%
# !git push -u origin main

# %%
# !cat ~/.git-credentials

# %%
import os
print(os.getcwd())
# Out:
# /home/cole/Desktop/Portfolio_Projects/cyclistic-analysis/notebooks

# %%
import os
os.chdir("/home/cole/Desktop/Portfolio_Projects/cyclistic-analysis")
df = pd.read_parquet("data/clean/trips_clean.parquet")

# %%
import os
print(os.getcwd())
# Out:
# /home/cole/Desktop/Portfolio_Projects/cyclistic-analysis/notebooks

# %%
import os
os.chdir("/home/cole/Desktop/Portfolio_Projects/cyclistic-analysis")

df = pd.read_parquet("data/clean/trips_clean.parquet")

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

os.chdir("/home/cole/Desktop/Portfolio_Projects/cyclistic-analysis")
print("CWD:", os.getcwd())

try:
    import duckdb
except ModuleNotFoundError as e:
    raise ModuleNotFoundError("duckdb not found. Install it with: pip install duckdb") from e

VIS_DIR = "visuals"
os.makedirs(VIS_DIR, exist_ok=True)
P = "data/clean/trips_clean.parquet"

def save_show(basename, dpi=150):
    path = os.path.join(VIS_DIR, f"{basename}.png")
    plt.tight_layout()
    plt.savefig(path, dpi=dpi)
    plt.show()
    plt.close()

# ==============
# 1) Average ride duration by rider type
# ==============
dur = duckdb.sql(f"""
    SELECT member_casual, AVG(duration_min)::DOUBLE AS mean
    FROM '{P}'
    GROUP BY 1
    ORDER BY 1
""").df()
ax = dur.set_index("member_casual")["mean"].plot(kind="bar")
ax.set_title("Average Ride Duration (min) by Rider Type")
ax.set_ylabel("Minutes")
save_show("avg_duration_by_rider")

# ==============
# 2) Rides by hour of day (line, split by rider)
# ==============
hourly = duckdb.sql(f"""
    SELECT EXTRACT(hour FROM started_at) AS hour,
           member_casual,
           COUNT(*) AS rides
    FROM '{P}'
    GROUP BY 1,2
    ORDER BY 1,2
""").df()

plt.figure()
for grp, g in hourly.groupby("member_casual"):
    g = g.sort_values("hour")
    plt.plot(g["hour"], g["rides"], marker="o", label=str(grp))
plt.title("Rides by Hour of Day")
plt.xlabel("Hour (0–23)")
plt.ylabel("Rides")
plt.legend(title="Rider Type")
save_show("rides_by_hour")

# ==============
# 3) Rides by weekday (grouped bar)
# ==============
wday = duckdb.sql(f"""
    SELECT EXTRACT(dow FROM started_at) AS weekday,
           member_casual,
           COUNT(*) AS rides
    FROM '{P}'
    GROUP BY 1,2
    ORDER BY 1,2
""").df()

wday_p = wday.pivot(index="weekday", columns="member_casual", values="rides").fillna(0)
ax = wday_p.plot(kind="bar")
ax.set_title("Rides by Weekday (0=Sun … 6=Sat)")
ax.set_xlabel("Weekday")
ax.set_ylabel("Rides")
plt.xticks(ticks=range(7), labels=["Sun","Mon","Tue","Wed","Thu","Fri","Sat"], rotation=0)
plt.legend(title="Rider Type")
save_show("rides_by_weekday_grouped")

# ==============
# 4) Monthly ride trend (stacked area)
# ==============
monthly = duckdb.sql(f"""
    SELECT strftime(started_at, '%Y-%m') AS month,
           member_casual,
           COUNT(*) AS rides
    FROM '{P}'
    GROUP BY 1,2
    ORDER BY 1,2
""").df()

pivot_m = monthly.pivot(index="month", columns="member_casual", values="rides").fillna(0)
ax = pivot_m.plot(kind="area")
ax.set_title("Monthly Ride Trend by Rider Type")
ax.set_xlabel("Month")
ax.set_ylabel("Rides")
plt.xticks(rotation=45, ha="right")
save_show("rides_by_month_area")

# ==============
# 5) Rideable type distribution by rider type (stacked bar)
# ==============
rtype = duckdb.sql(f"""
    SELECT member_casual, rideable_type, COUNT(*) AS rides
    FROM '{P}'
    GROUP BY 1,2
    ORDER BY 1,2
""").df()

rtype_p = rtype.pivot(index="member_casual", columns="rideable_type", values="rides").fillna(0)
ax = rtype_p.plot(kind="bar", stacked=True)
ax.set_title("Rideable Type Distribution by Rider Type")
ax.set_xlabel("Rider Type")
ax.set_ylabel("Rides")
save_show("rideable_type_by_rider_stacked")

# ==============
# 6) Top 10 start stations (overall)
# ==============
top_starts = duckdb.sql(f"""
    SELECT start_station_name, COUNT(*) AS rides
    FROM '{P}'
    WHERE start_station_name IS NOT NULL
    GROUP BY 1
    ORDER BY rides DESC
    LIMIT 10
""").df()

top_starts = top_starts.sort_values("rides")
ax = top_starts.set_index("start_station_name")["rides"].plot(kind="barh")
ax.set_title("Top 10 Start Stations (Overall)")
ax.set_xlabel("Rides")
save_show("top10_start_stations")

# ==============
# 7) Heatmap: Weekday × Hour (rides)
# ==============
heat_df = duckdb.sql(f"""
    SELECT EXTRACT(dow FROM started_at) AS weekday,
           EXTRACT(hour FROM started_at) AS hour,
           COUNT(*) AS rides
    FROM '{P}'
    GROUP BY 1,2
""").df()

heat_p = heat_df.pivot(index="weekday", columns="hour", values="rides").reindex(index=range(7), columns=range(24)).fillna(0)

plt.figure()
plt.imshow(heat_p.values, aspect="auto", origin="upper")
plt.colorbar(label="Rides")
plt.xlabel("Hour (0–23)")
plt.ylabel("Weekday (0=Sun … 6=Sat)")
plt.title("Heatmap: Rides by Weekday × Hour")
save_show("heatmap_weekday_hour")

print("Done. Saved PNGs to:", VIS_DIR)
# Out:
# CWD: /home/cole/Desktop/Portfolio_Projects/cyclistic-analysis
# Done. Saved PNGs to: visuals
